# %%
# 문제 정수 7과 정수 3을 더한 결과를 구하는 파이썬 코드를 작성하세요.
print(7+3)
# Out:
# 10

# %%
# 문제 주민등록번호 변수를 각각 연월일과 숫자로 나누어 출력하세요.
pin = "881120-1068234"
print('연월일 :'+ pin[:6])
print(pin[-7:])
print('연 :'+ pin[0]+pin[1])
print('월 :'+ pin[2]+pin[3])
print('일 :'+pin[4]+pin[5])
# Out:
# 연월일 :881120
# 1068234
# 연 :88
# 월 :11
# 일 :20

# %%
# 문제 주어진 실수 3.1415를 소수점 두 번째 자리에서 반올림하는 파이썬 코드를 작성하세요.
a=3.1415
print(round(a,1))
# Out:
# 3.1

# %%
# 문제 변수 a를 a/b/c/d로 변환하여 출력하세요.
a = 'a:b:c:d'
print(a.replace(":","/"))
# Out:
# a/b/c/d

# %%
# 문제 주어진 문자열 'Hello, World!'에서 첫 번째 단어 'Hello'만 추출하는 
# 파이썬 코드를 작성하세요.
a = 'Hello, World!'
print(a[0:4+1])
# Out:
# Hello

# %%
# 문제 아래의 a변수를 'Life is too short'문자열로 변환하여 출력해보세요.
a = ['Life','is','too','short']
print(" ".join(a))
# Out:
# Life is too short

# %%
# 문제 주어진 문자열 'Python'의 모든 문자를 대문자로 변환하는 파이썬 코드를 작성하세요.
a = "Python"
print(a.upper())
# Out:
# PYTHON

# %%
# 문제 주어진 리스트 [1, 2, 3, 4, 5]에서 첫 번째 원소와 마지막 원소를 교환하는 
# 파이썬 코드를 작성하세요.
# 자바, 파이썬 둘다 가능한 방식
a=[1, 2, 3, 4, 5]
b= a[0]
a[0] = a[4]
a[4] = b
print(a)
# 파이썬에서만 가능한 방식
a=[1, 2, 3, 4, 5]
a[0],a[4] = a[4],a[0]
print(a)
# Out:
# [5, 2, 3, 4, 1]
# [5, 2, 3, 4, 1]

# %%
# 문제 주어진 리스트 [5, 2, 7, 1, 9]를 오름차순 정렬하는 파이썬 코드를 작성하세요.
a = [5, 2, 7, 1, 9]
a.sort()
print(a)
# Out:
# [1, 2, 5, 7, 9]

# %%
# 문제 주어진 리스트 [1,3,5,4,2]를 내림차순으로 정렬하는 파이썬 코드를 작성하세요.
a = [1,3,5,4,2]
a.sort(reverse=True)
print(a)
# Out:
# [5, 4, 3, 2, 1]

# %%
# 문제 주어진 튜플 ('apple', 'banana', 'cherry')에서 첫 번째 원소 'apple'을 추출하는 
# 파이썬 코드를 작성하세요.
a = ('apple', 'banana', 'cherry')
print(a[0])
# Out:
# ('apple', 'banana')

# %%
# 문제 두 개의 튜플 (1, 2, 3)과 (4, 5, 6)을 병합하여 새로운 튜플 (1, 2, 3, 4, 5, 6)을 
# 생성하는 파이썬 코드를 작성하세요.
a = (1,2,3)
b = (4,5,6)
print(a+b)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
# 문제 주어진 딕셔너리 {'apple': 3, 'banana': 5, 'cherry': 2}에서 'banana'의 값을 추출하는 
# 파이썬 코드를 작성하세요
a = {'apple': 3, 'banana': 5, 'cherry': 2}
print(a['banana'])
# Out:
# 5

# %%
# 문제 주어진 딕셔너리 {'apple': 3, 'banana': 5, 'cherry': 2}에 'orange': 4를 추가하는 
# 파이썬 코드를 작성하세요.
a = {'apple': 3, 'banana': 5, 'cherry': 2}
a['orange'] = 4
print(a)
# Out:
# {'apple': 3, 'banana': 5, 'cherry': 2, 'orange': 4}

# %%
# 문제 주어진 두 집합 {1, 2, 3}과 {2, 3, 4}의 교집합을 구하는 파이썬 코드를 작성하세요
a = {1,2,3}
b = {2,3,4}
print(a & b)
print(a.intersection(b))
# Out:
# {2, 3}
# {2, 3}

# %%
# 문제 주어진 두 불 값 True와 False를 AND 연산하는 파이썬 코드를 작성하세요.
a = True
b = False
print (a and b)
# Out:
# False

# %%
# 문제 아래의 a리스트에서 중복을 제거하여 출력해보세요.
a = [1,1,1,2,2,2,3,3,4,4,5]
a = set(a)
print(a)
# Out:
# {1, 2, 3, 4, 5}
