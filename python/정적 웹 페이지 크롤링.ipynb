# %%
from bs4 import BeautifulSoup
html = '<h1 id="title">한빛출판네트워크</h1><div class="top"><ul class="menu"><li><a href="http://www.hanbit.co.kr/member/login.html" class="login">로그인</a></li><li><a href="http://www.hanbit.co.kr/member/media">한빛미디어</li><li><a href="http://www.hanbit.co.kr/member/academy">한빛아카데미</li></ul></div>'
soup = BeautifulSoup(html, 'html.parser')
print(soup)
print(soup.h1)
print(soup.div)
print(soup.a)
print(soup.li)
# find_all("속성") : 모든 속성에 맞는 캐그를 찾아 리스트로 반환
liTag = soup.find_all("a")
for i in liTag:
    print(i)
# find("속성") : 속성을 이용한 특정 태그를 찾아 반환
login = soup.find('a', attrs={'class' : 'login'})
print(login)
id = soup.find(attrs={'id':'title'})
print(id)
# select("css선택자") : css설정시 사용하는 선택자를 이용하여 찾는 함수
li_list = soup.select("div>ul.menu>li")
for li in li_list:
    print(li)
# Out:
# <h1 id="title">한빛출판네트워크</h1><div class="top"><ul class="menu"><li><a class="login" href="http://www.hanbit.co.kr/member/login.html">로그인</a></li><li><a href="http://www.hanbit.co.kr/member/media">한빛미디어</a></li><li><a href="http://www.hanbit.co.kr/member/academy">한빛아카데미</a></li></ul></div>
# <h1 id="title">한빛출판네트워크</h1>
# <div class="top"><ul class="menu"><li><a class="login" href="http://www.hanbit.co.kr/member/login.html">로그인</a></li><li><a href="http://www.hanbit.co.kr/member/media">한빛미디어</a></li><li><a href="http://www.hanbit.co.kr/member/academy">한빛아카데미</a></li></ul></div>
# <a class="login" href="http://www.hanbit.co.kr/member/login.html">로그인</a>
# <li><a class="login" href="http://www.hanbit.co.kr/member/login.html">로그인</a></li>
# <a class="login" href="http://www.hanbit.co.kr/member/login.html">로그인</a>
# <a href="http://www.hanbit.co.kr/member/media">한빛미디어</a>
# <a href="http://www.hanbit.co.kr/member/academy">한빛아카데미</a>
# ...

# %%
from bs4 import BeautifulSoup
html = '<h1 id="title">한빛출판네트워크</h1><div class="top"><ul class="menu"><li><a href="http://www.hanbit.co.kr/member/login.html" class="login">로그인</a></li><li><a href="http://www.hanbit.co.kr/member/media">한빛미디어</li><li><a href="http://www.hanbit.co.kr/member/academy">한빛아카데미</li></ul></div>'
soup = BeautifulSoup(html, 'html.parser')
aTag = soup.a
print(aTag)
# attrs : 속성들을 딕셔너리 형식으로 저장하는 변수
print(aTag.attrs)
# 딕셔너리에서 데이터를 꺼내는 방식으로 속성의 값을 출력할 수 있음
print(aTag['class'])
print(aTag['href'])
# Out:
# <a class="login" href="http://www.hanbit.co.kr/member/login.html">로그인</a>
# {'href': 'http://www.hanbit.co.kr/member/login.html', 'class': ['login']}
# ['login']
# http://www.hanbit.co.kr/member/login.html

# %%
from bs4 import BeautifulSoup
import urllib.request
result = []
for page in range(1,2):
    hollys_url = f'https://www.hollys.co.kr/store/korea/korStore2.do?pageNo={page}&sido=&gugun=&store='
    print(hollys_url)
    html = urllib.request.urlopen(hollys_url)
    soupHollys = BeautifulSoup(html,'html.parser')
    tag_tbody = soupHollys.find('tbody')
    for store in tag_tbody.find_all("tr"):
        if len(store) <= 3 :
            break
        store_td = store.find_all('td')
        store_name = store_td[1].string
        store_sido = store_td[0].string
        store_address = store_td[3].string
        store_phone = store_td[5].string
        store_flag = store_td[2].string
        result.append([store_name]+[store_sido]+[store_address]+[store_phone])
for i in result:
    print(i)
# Out:
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=1&sido=&gugun=&store=
# ['평택이충DT점', '경기 평택시', '경기도 평택시 추담로 30 (이충동 59) .', '031-666-7034']
# ['충무로역점', '서울 중구', '서울특별시 중구 퇴계로36길 2 (필동2가, 동국대학교충무로영상센터) .', '02-2268-8960']
# ['평택지산점', '경기 평택시', '경기도 평택시 지산로 10, 가이아프레지던스 1층  지산동 808-4, 101,102호', '031-8029-9005']
# ['FKI타워2호점', '서울 영등포구', '서울특별시 영등포구 여의대로 24 (여의도동, 에프케이아이타워) 1층', '02-782-3647']
# ['부산명지강변DT점', '부산 강서구', '부산광역시 강서구 르노삼성대로 586 (명지동) 1-3층', '051-710-2800']
# ['전북대의과대점', '전북 전주시 덕진구', '전북특별자치도 전주시 덕진구 건지로 20 (금암동, 전북대학교병원) 의학계학생회관1층', '063-270-4597']
# ['(하)내린천휴게소점', '강원 인제군', '강원도 인제군 상남면 서울양양고속도로 117 양양방향 내린천휴게소, 1층', '.']
# ['(상)내린천휴게소점', '강원 인제군', '강원도 인제군 상남면 서울양양고속도로 117  서울방향 내린천휴게소 4층', '.']
# ['대전호수공원점', '대전 서구', '대전광역시 서구 도안동로 234-42 1,2층 도안동 2336', '070-8862-8826']
# ['국립부경대청운관점', '부산 남구', '부산광역시 남구 용소로 45 (대연동, 국립부경대학교대연캠퍼스) 청운관 1층', '051-629-7419']
